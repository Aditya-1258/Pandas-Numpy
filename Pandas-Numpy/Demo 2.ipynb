# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Online Course.csv')

# %%
data
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35           3137.0         18.0            68          All Levels
# 1    75           1593.0          1.0            41  Intermediate Level
# 2    75            482.0          1.0            47  Intermediate Level
# 3    75            850.0          3.0            43  Intermediate Level
# 4    75            940.0          3.0            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
data.tail(10)
# Out:
#       course_id                                       course_title  is_paid  \
# 3672    1031698                        You Can Play Jazz Saxophone     True
# 3673      79364                       Your Business by the Numbers     True
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3675     551170                         Your First Course on Piano     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
data.describe()
# Out:
#           course_id  num_subscribers   num_reviews  num_lectures
# count  3.682000e+03      3657.000000   3670.000000   3682.000000
# mean   6.766121e+05      3198.233525    156.451226     40.065182
# std    3.436355e+05      9528.468323    936.459886     50.373299
# min    8.324000e+03         0.000000      0.000000      0.000000
# 25%    4.078430e+05       109.000000      4.000000     15.000000
# 50%    6.885580e+05       898.000000     17.500000     25.000000
# 75%    9.617515e+05      2528.000000     67.000000     45.000000
# max    1.282064e+06    268923.000000  27445.000000    779.000000

# %%
data.isna()
# Out:
#       course_id  course_title  is_paid  price  num_subscribers  num_reviews  \
# 0         False         False    False  False            False        False
# 1         False         False    False  False            False        False
# 2         False         False    False  False            False        False
# 3         False         False    False  False            False        False
# 4         False         False    False  False            False        False
# ...         ...           ...      ...    ...              ...          ...
# 3677      False         False    False  False            False        False
# 3678      False         False    False  False            False        False
# 3679      False         False    False  False            False        False
# 3680      False         False    False  False            False        False
# 3681      False         False    False  False            False        False
#
# ...

# %%
data.isna().sum()
# Out:
# course_id               0
# course_title            0
# is_paid                 0
# price                  11
# num_subscribers        25
# num_reviews            12
# num_lectures            0
# level                   0
# content_duration        0
# published_timestamp     3
# subject                 4
# dtype: int64

# %%
data.loc[:,'course_title']
# Out:
# 0       #1 Piano Hand Coordination: Play 10th Ballad i...
# 1       #10 Hand Coordination - Transfer Chord Ballad ...
# 2       #12 Hand Coordination: Let your Hands dance wi...
# 3       #4 Piano Hand Coordination: Fun Piano Runs in ...
# 4       #5  Piano Hand Coordination:  Piano Runs in 2 ...
#                               ...
# 3677    Your Own Site in 45 Min: The Complete Wordpres...
# 3678      Your Second Course on Piano: Two Handed Playing
# 3679    Zend Framework 2: Learn the PHP framework ZF2 ...
# 3680    Zoho Books Gestion Financière d'Entreprise pas...
# 3681                  Zombie Apocalypse Photoshop Actions
# Name: course_title, Length: 3682, dtype: object

# %%
df = data.dropna()

# %%
df.isna().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
data['price'].fillna(0,inplace = True)

# %%
data.isna().sum()
# Out:
# course_id               0
# course_title            0
# is_paid                 0
# price                   0
# num_subscribers        25
# num_reviews            12
# num_lectures            0
# level                   0
# content_duration        0
# published_timestamp     3
# subject                 4
# dtype: int64

# %%
data.nunique()
# Out:
# course_id              3676
# course_title           3667
# is_paid                   2
# price                    39
# num_subscribers        2182
# num_reviews             511
# num_lectures            229
# level                     4
# content_duration        109
# published_timestamp    3673
# subject                   4
# dtype: int64

# %%
data.set_index('course_id',inplace=True)

# %%
data
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 288942     #1 Piano Hand Coordination: Play 10th Ballad i...     True    35
# 1170074    #10 Hand Coordination - Transfer Chord Ballad ...     True    75
# 1193886    #12 Hand Coordination: Let your Hands dance wi...     True    75
# 1116700    #4 Piano Hand Coordination: Fun Piano Runs in ...     True    75
# 1120410    #5  Piano Hand Coordination:  Piano Runs in 2 ...     True    75
# ...                                                      ...      ...   ...
# 328960     Your Own Site in 45 Min: The Complete Wordpres...     True   120
# 552700       Your Second Course on Piano: Two Handed Playing     True    70
# 631754     Zend Framework 2: Learn the PHP framework ZF2 ...     True    40
# 1225194    Zoho Books Gestion Financière d'Entreprise pas...    False  Free
# 964478                   Zombie Apocalypse Photoshop Actions     True    50
#
# ...

# %%
data.sort_values('course_id',ascending = False)
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 1282064    Cryptocurrency (BTC & ETH) Investment & Tradin...     True    20
# 1277924                              Angular 4 Front To Back     True    40
# 1276364          Bitcoin & Ethereum Course (2 Course Bundle)     True   200
# 1276182    Options Trading Foundation: Your journey to co...     True    95
# 1276020                  Photoshop para iniciante - o básico     True    30
# ...                                                      ...      ...   ...
# 11475                       Become a Certified Web Developer     True   100
# 11174                    Become a Web Developer from Scratch     True   120
# 11153         Learn jQuery: An In-depth Course For Beginners     True    50
# 8325                 HTML Tutorial: HTML & CSS for Beginners     True    20
# 8324                                Javascript for Beginners     True    20
#
# ...

# %%
data.columns
# Out:
# Index(['course_title', 'is_paid', 'price', 'num_subscribers', 'num_reviews',
#        'num_lectures', 'level', 'content_duration', 'published_timestamp',
#        'subject'],
#       dtype='object')

# %%
data.columns.dtype
# Out:
# dtype('O')

# %%
new_row=pd.DataFrame({'course_title':'Manga', 'is_paid':False, 'price':'Free', 'num_subscribers':'1', 'num_reviews':'0',
       'num_lectures':'100000', 'level':'All Levels', 'content_duration':'1000 hours', 'published_timestamp':'2023-07-09T05:43:31Z',
       'subject':'Martial arts'},index=[68249232])

df1=pd.concat([data,new_row])

# %%
df1
# Out:
#                                                course_title  is_paid price  \
# 288942    #1 Piano Hand Coordination: Play 10th Ballad i...     True    35
# 1170074   #10 Hand Coordination - Transfer Chord Ballad ...     True    75
# 1193886   #12 Hand Coordination: Let your Hands dance wi...     True    75
# 1116700   #4 Piano Hand Coordination: Fun Piano Runs in ...     True    75
# 1120410   #5  Piano Hand Coordination:  Piano Runs in 2 ...     True    75
# ...                                                     ...      ...   ...
# 552700      Your Second Course on Piano: Two Handed Playing     True    70
# 631754    Zend Framework 2: Learn the PHP framework ZF2 ...     True    40
# 1225194   Zoho Books Gestion Financière d'Entreprise pas...    False  Free
# 964478                  Zombie Apocalypse Photoshop Actions     True    50
# 68249232                                              Manga    False  Free
#
# ...

# %%
c=data['num_subscribers']>100

# %%
data[c].sort_values('num_subscribers')
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 903326                                       CPA 10 COMPLETO     True    25
# 1223000      Innovators and innovation: Travel through time!     True    50
# 1019918            Master Angular 2 - The No Nonsense Course     True    25
# 315812                        Gibson's Learn & Master Guitar     True    50
# 1178762    WordPress Development - Themes and Plugins Com...     True   200
# ...                                                      ...      ...   ...
# 764164                 The Complete Web Developer Course 2.0     True   200
# 173548     Build Your First Website in 1 Week with HTML5 ...    False  Free
# 625204                            The Web Developer Bootcamp     True   200
# 59014                         Coding for Entrepreneurs Basic    False  Free
# 41295                   Learn HTML5 Programming From Scratch    False  Free
#
# ...

# %%
c.value_counts()
# Out:
# num_subscribers
# True     2770
# False     912
# Name: count, dtype: int64

# %%
for i in list(data):
    print(data[i][59014])
# Out:
# Coding for Entrepreneurs Basic
# False
# Free
# 161029.0
# 279.0
# 27
# Beginner Level
# 3.5 hours
# 2013-06-09T15:51:55Z
# Web Development

# %%
import numpy as np

# %%
data1=data.set_index(np.arange(0,len(data)))

# %%
data
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 288942     #1 Piano Hand Coordination: Play 10th Ballad i...     True    35
# 1170074    #10 Hand Coordination - Transfer Chord Ballad ...     True    75
# 1193886    #12 Hand Coordination: Let your Hands dance wi...     True    75
# 1116700    #4 Piano Hand Coordination: Fun Piano Runs in ...     True    75
# 1120410    #5  Piano Hand Coordination:  Piano Runs in 2 ...     True    75
# ...                                                      ...      ...   ...
# 328960     Your Own Site in 45 Min: The Complete Wordpres...     True   120
# 552700       Your Second Course on Piano: Two Handed Playing     True    70
# 631754     Zend Framework 2: Learn the PHP framework ZF2 ...     True    40
# 1225194    Zoho Books Gestion Financière d'Entreprise pas...    False  Free
# 964478                   Zombie Apocalypse Photoshop Actions     True    50
#
# ...

# %%
data1
# Out:
#                                            course_title  is_paid price  \
# 0     #1 Piano Hand Coordination: Play 10th Ballad i...     True    35
# 1     #10 Hand Coordination - Transfer Chord Ballad ...     True    75
# 2     #12 Hand Coordination: Let your Hands dance wi...     True    75
# 3     #4 Piano Hand Coordination: Fun Piano Runs in ...     True    75
# 4     #5  Piano Hand Coordination:  Piano Runs in 2 ...     True    75
# ...                                                 ...      ...   ...
# 3677  Your Own Site in 45 Min: The Complete Wordpres...     True   120
# 3678    Your Second Course on Piano: Two Handed Playing     True    70
# 3679  Zend Framework 2: Learn the PHP framework ZF2 ...     True    40
# 3680  Zoho Books Gestion Financière d'Entreprise pas...    False  Free
# 3681                Zombie Apocalypse Photoshop Actions     True    50
#
#       num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
grp = data.groupby('subject')

# %%
grp.first()
# Out:
#                                                           course_title  \
# subject
# Business Finance     * An Integrated Approach to the Fundamentals o...
# Graphic Design       :::Beginners Guide To Creating Amazing Images ...
# Musical Instruments  #1 Piano Hand Coordination: Play 10th Ballad i...
# Web Development                                             1 Hour CSS
#
#                      is_paid price  num_subscribers  num_reviews  \
# subject
# Business Finance        True   200            134.0         14.0
# Graphic Design          True    25             72.0          5.0
# Musical Instruments     True    35           3137.0         18.0
# Web Development         True   100          18324.0        333.0
#
#                      num_lectures           level content_duration  \
# subject
# Business Finance              123      All Levels        5.5 hours
# Graphic Design                 17  Beginner Level           1 hour
# ...

# %%
grp.groups
# Out:
# {'Business Finance': [768028, 738910, 591880, 145220, 302450, 157336, 315716, 638966, 486240, 146454, 54246, 1089610, 159388, 975982, 155616, 166842, 1231958, 889824, 606928, 988804, 614668, 172298, 158140, 1171994, 66383, 247558, 904240, 302484, 366514, 1214144, 421546, 1250694, 829182, 1005312, 1100746, 548764, 557436, 557208, 1219820, 640100, 317572, 174800, 402836, 267984, 607362, 174790, 354324, 1029322, 471440, 531710, 510178, 494800, 671548, 773650, 441112, 521234, 138004, 739972, 577256, 655300, 378464, 394636, 258174, 298044, 508796, 48841, 221306, 567070, 640062, 1193288, 19653, 343886, 415802, 891490, 455452, 262370, 467238, 866584, 298558, 1275790, 722682, 42146, 658766, 42634, 1269590, 530768, 1263966, 677802, 849896, 858764, 869716, 863998, 352782, 212952, 960786, 754156, 594936, 258232, 517938, 975074, ...], 'Graphic Design': [206592, 1165268, 1164876, 599652, 1269190, 794036, 435626, 413713, 223884, 766320, 814200, 733654, 1139792, 1093446, 1009068, 1089062, 935108, 9
# ...

# %%
data.columns
# Out:
# Index(['course_title', 'is_paid', 'price', 'num_subscribers', 'num_reviews',
#        'num_lectures', 'level', 'content_duration', 'published_timestamp',
#        'subject'],
#       dtype='object')

# %%
data.groupby('subject')['num_subscribers'].sum()
# Out:
# subject
# Business Finance       1863603.0
# Graphic Design         1062293.0
# Musical Instruments     833314.0
# Web Development        7926433.0
# Name: num_subscribers, dtype: float64

# %%
data.groupby('subject')['num_subscribers'].max()
# Out:
# subject
# Business Finance        65576.0
# Graphic Design          53851.0
# Musical Instruments    101154.0
# Web Development        268923.0
# Name: num_subscribers, dtype: float64

# %%
data.groupby('subject')['num_subscribers'].median()
# Out:
# subject
# Business Finance        483.0
# Graphic Design          384.0
# Musical Instruments     137.0
# Web Development        2433.5
# Name: num_subscribers, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
dict1=data.groupby('subject')['num_subscribers'].sum().to_dict()
a=[]
b=[]
for i,j in dict1.items():
    a.append(i)
    b.append(j)
    print(i,j)
# Out:
# Business Finance 1863603.0
# Graphic Design 1062293.0
# Musical Instruments 833314.0
# Web Development 7926433.0

# %%
plt.plot(a,b)

# %%
data['published_timestamp'] = pd.to_datetime(data.published_timestamp)
# or by to_as
data.dtypes
# Out:
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                    float64
# num_reviews                        float64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data['Year'] = data['published_timestamp'].dt.year

# %%
data.groupby('Year')['num_subscribers'].sum()
# Out:
# Year
# 2011.0     119028.0
# 2012.0     555339.0
# 2013.0    1723438.0
# 2014.0    1922545.0
# 2015.0    3436915.0
# 2016.0    2953374.0
# 2017.0     981558.0
# Name: num_subscribers, dtype: float64

# %%
dict2=data.groupby('Year')['num_subscribers'].sum().to_dict()
c,d=[],[]
for i,j in dict2.items():
    c.append(i)
    d.append(j)
    print(i,j)
# Out:
# 2011.0 119028.0
# 2012.0 555339.0
# 2013.0 1723438.0
# 2014.0 1922545.0
# 2015.0 3436915.0
# 2016.0 2953374.0
# 2017.0 981558.0

# %%
plt.plot(c,d)

# %%
def change_free(d):
#     for i in len(data): 
#         if data['price'][i] == 'Free':
#             data['price'][i] = 0
#     return data['price']
    if d=='Free':
        d='0'
    return d

# %%
# data['price']=data['price'].astype(str)
data['price'] = data['price'].apply(change_free)

# %%
#data['price'] = data['price'].replace('Free', 0)
data
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 288942     #1 Piano Hand Coordination: Play 10th Ballad i...     True    35
# 1170074    #10 Hand Coordination - Transfer Chord Ballad ...     True    75
# 1193886    #12 Hand Coordination: Let your Hands dance wi...     True    75
# 1116700    #4 Piano Hand Coordination: Fun Piano Runs in ...     True    75
# 1120410    #5  Piano Hand Coordination:  Piano Runs in 2 ...     True    75
# ...                                                      ...      ...   ...
# 328960     Your Own Site in 45 Min: The Complete Wordpres...     True   120
# 552700       Your Second Course on Piano: Two Handed Playing     True    70
# 631754     Zend Framework 2: Learn the PHP framework ZF2 ...     True    40
# 1225194    Zoho Books Gestion Financière d'Entreprise pas...    False     0
# 964478                   Zombie Apocalypse Photoshop Actions     True    50
#
# ...

# %%
data['price'] = data['price'].astype(int)

# %%
data[(data.subject == 'Graphic Design')&(data.price <= 200)]
# Out:
#                                                 course_title  is_paid  price  \
# course_id
# 206592     :::Beginners Guide To Creating Amazing Images ...     True     25
# 1165268    15  Motion Graphic Elements in After Effect (S...     True     30
# 1164876    3DS MAX - Learn 3Ds MAX tutorial for Beginners...     True     20
# 599652                        48 Logo Designs and Techniques     True     20
# 1269190            7 Secrets To Designing In Black and White     True    100
# ...                                                      ...      ...    ...
# 1131780    Whiteboard Animation, Beginner To Expert - In ...     True     20
# 908664     Word Swag : Create Stunning Images with the Wo...     True    100
# 1122306           Wordpress: Comment utiliser le thème FABLE     True     20
# 144222     YOU can Draw, Shade and Paint a Mixed Media Gi...     True     30
# 964478                   Zombie Apocalypse Photoshop Actions     True     50
#
# ...
